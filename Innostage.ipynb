# %% [markdown]
# <a href="https://colab.research.google.com/github/zhekagod/InnostageDataScience/blob/main/Innostage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Библиотеки

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Входные и начальные данные

# %%
data = pd.read_csv('/content/Innostage/temperature.csv')
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-633aab1879b6> in <cell line: 1>()
# ----> 1 data = pd.read_csv('/content/Innostage/temperature.csv')
#       2 data
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
def _plot_series(series, series_name, series_index=0):
  from matplotlib import pyplot as plt
  import seaborn as sns
  palette = list(sns.palettes.mpl_palette('Dark2'))
  xs = series['index']
  ys = series['Temperature']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_3.sort_values('index', ascending=True)
_plot_series(df_sorted, '')
sns.despine(fig=fig, ax=ax)
plt.xlabel('index')
_ = plt.ylabel('Temperature')

# %%
# !pip install sktime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.6/20.6 MB 53.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 kB 14.4 MB/s eta 0:00:00
# ...

# %%
from sktime.utils.plotting import plot_series

# %%
plt.figure(figsize=(15, 6))
y = data.Time

plot_series(y)
plt.title('Изменение температуры с 2010-01-01 по 2017-12-29')
plt.tick_params(axis = 'both', which = 'major', labelsize = 14);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-615e233e2143> in <cell line: 2>()
#       1 plt.figure(figsize=(15, 6))
# ----> 2 y = data.Time
#       3
#       4 plot_series(y)
#       5 plt.title('Изменение температуры с 2010-01-01 по 2017-12-29')
#
# NameError: name 'data' is not defined
